# %% [markdown]
# ## Gathered Notebook
#
# This notebook was generated by the Gather Extension. The intent is that it contains only the code and cells required to produce the same results as the cell originally selected for gathering. Please note that the Python analysis is quite conservative, so if it is unsure whether a line of code is necessary for execution, it will err on the side of including it.
#
# **Please let us know if you are satisfied with what was gathered [here](https://aka.ms/gatherfeedback).**
#
# Thanks

# %% [markdown]
# Predicting Student Grades

# %% [markdown]
# Loading Data

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
import pickle

# %%
df = pd.read_csv("student-mat.csv", sep=';') #Dataset is separated by semicolons therefore need to sep by ;

# %%
data = df[["G1", "G2", "G3", "studytime", "failures", "absences"]] #Want to focus on the following attributes: how their study time, failures, and absences affect their final grades.

# %%
predict = "G3" # We want to predict their grade for their third period
X = np.array(data.drop([predict], 1)) #Dropping the G3 column so we can use the df as our input
y = np.array(data[predict]) #Only using G3 column as our result
# Out:
# C:\Users\t-nguyenamy\AppData\Local\Temp\ipykernel_12420\2279691604.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = np.array(data.drop([predict], 1)) #Dropping the G3 column so we can use the df as our input

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1) #Testing on 10% of our dataset

# %%
# Defining the model that we will be using 
linear = linear_model.LinearRegression()

# %%
linear = linear_model.LinearRegression()

# %%
linear.fit(X_train, y_train)
accuracy = linear.score(X_test, y_test)
accuracy
# Out:
# 0.7778640824727893

# %%
best = 0
for _ in range(20):
    x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size=0.1)
    linear = linear_model.LinearRegression()
    linear.fit(x_train, y_train)
    acc = linear.score(x_test, y_test)
    print("Accuracy: " + str(acc))
    if acc > best:
        best = acc
        with open("studentgrades.pickle", "wb") as f:
            pickle.dump(linear, f)
pickle_in = open("studentgrades.pickle", "rb")
linear = pickle.load(pickle_in)
# Out:
# Accuracy: 0.859910500584387
# Accuracy: 0.8127124282059225
# Accuracy: 0.8164215184488277
# Accuracy: 0.6686283545826828
# Accuracy: 0.9561451518230295
# Accuracy: 0.8025299113804427
# Accuracy: 0.8613193325547928
# Accuracy: 0.7947545278565158
# Accuracy: 0.8516708161113744
# Accuracy: 0.7575842143991975
# Accuracy: 0.880271045663255
# Accuracy: 0.8797188733448836
# Accuracy: 0.824760665171012
# Accuracy: 0.7137222334290747
# Accuracy: 0.7538694695999741
# Accuracy: 0.7505798140996421
# Accuracy: 0.8088545905470603
# Accuracy: 0.6812156433205921
# Accuracy: 0.7925469216941243
# Accuracy: 0.8595494978590541
